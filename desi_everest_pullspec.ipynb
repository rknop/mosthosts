# %%
# %matplotlib inline
# matplotlib widget doesn't seem to work
# %matplotlib widget
import sys
import math
import logging
import numpy as np
import psycopg2
import psycopg2.extras
from matplotlib import pyplot
from astropy.io import fits

from everest_specinfo import TargetNotFound, SpectrumInfo

logger = logging.getLogger("main")
ch = logging.StreamHandler(sys.stderr)
logger.addHandler(ch)
formatter = logging.Formatter(
    f"[%(asctime)s - %(levelname)s] - %(message)s"
)
ch.setFormatter(formatter)
logger.setLevel( logging.INFO )

# %%
with open("/global/homes/r/raknop/secrets/decatdb_desi_desi") as ifp:
    (dbuser,dbpasswd) = ifp.readline().strip().split()
# dbuser = "desi"
# dbpasswd = "Put right password here"
desidb = psycopg2.connect( f"dbname='desi' host='decatdb.lbl.gov' user='{dbuser}' password='{dbpasswd}'",
                          cursor_factory=psycopg2.extras.RealDictCursor )

# %%
# Put the name (from the "snname" column") of the MostHosts supernova you want to poke at
mosthost_name = 'ZTF18aakjgzb'

q = "SELECT ra,dec FROM mosthosts.mosthosts WHERE snname=%(snname)s"
cursor = desidb.cursor()
logger.debug( f'Running query : {cursor.mogrify(q, { "snname": mosthost_name })}' )
cursor.execute( q, { "snname": mosthost_name } )
rows = cursor.fetchall()
cursor.close()
if len(rows) == 0:
    raise Exception( f'{mosthost_name} not found in mosthosts' )
print( f'{mosthost_name} has {len(rows)} entries in the MostHosts table' )

allhostdata = []

logger.info( 'Looking for everest data on hosts...' )
for num, row in enumerate( rows ):
    ra = row['ra']
    dec = row['dec']
    try:
        specinfo = SpectrumInfo( ra, dec, desidb, logger=logger )
    except TargetNotFound as ex:
        logger.exception( f'No everest spectra found for host {num} of {mosthost_name} at ({ra:.4f}, {dec:.4f})' )
        continue
    allhostdata.append( specinfo )
    print( f'Host: ra = {ra:.5f}, dec = {dec:.5f}' )
logger.info( 'Done looking for everest data on hosts.' )
print( f'Found spectra of {len(allhostdata)} hosts for {mosthost_name}' )
# Out:
# [2021-10-06 16:23:37,827 - INFO] - Looking for everest data on hosts...
# [2021-10-06 16:23:37,828 - INFO] - Looking for everest spectra at (240.5221, 55.2009)
# [2021-10-06 16:23:37,851 - INFO] - Done looking for everest spectra at (240.5221, 55.2009)
# [2021-10-06 16:23:37,852 - INFO] - Looking for everest spectra at (240.5238, 55.2036)
# [2021-10-06 16:23:37,975 - INFO] - Done looking for everest spectra at (240.5238, 55.2036)
# [2021-10-06 16:23:37,976 - INFO] - Done looking for everest data on hosts.
# ZTF18aakjgzb has 2 entries in the MostHosts table
# Host: ra = 240.52207, dec = 55.20090
# Host: ra = 240.52378, dec = 55.20360
# Found spectra of 2 hosts for ZTF18aakjgzb

# %%
# Plot limits; array, one for each target (not spectrum).  Make them all None to autoscale.
fmin = [-10, -2] # None # [-3, 0 ]
fmax = [30, 10] # None # [ 3, 50 ]
λmin = 4500
λmax = 7500

plotcolors = { 'B': 'b',
               'R': 'r',
               'Z': 'saddlebrown' }

targnum = -1
for hostcollection in allhostdata:
    for targetid in hostcollection.targetids:
        targnum += 1
        specinfo = hostcollection.info_for_targetid( targetid )
        specnum = 0
        for spec in specinfo:
            specnum += 1
            print( f'{spec["filename"]} : {spec["device_loc"]}' )
            with fits.open(spec["filename"]) as hdulist:
                w = np.where( hdulist['FIBERMAP'].data['DEVICE_LOC'] == spec["device_loc"] )[0]
                if len(w) != 1:
                    raise Exception( f'Found {len(w)} things in the fibermap with DEVICE_LOC={spec["device_loc"]}' )
                index = w[0]
                fig = pyplot.figure( figsize=(15,6), tight_layout=True )
                ax = fig.add_subplot( 1, 1, 1 )
                title = ( f'Target {targetid} : Spectrum {specnum} '
                          # f'Tile {spec["tileid"]} on night {spec["night"]} '
                          f'with z={spec["z"]:.3f}' )
                if spec["zwarn"] != 0:
                    title += f' (zwarn={spec["zwarn"]})'
                title += f' (Δχ²={spec["deltachi2"]:.3g})'
                ax.set_title( title, fontsize=18 )
                ax.set_xlabel( 'λ (Å)', fontsize=18 )
                ax.set_ylabel( 'flux', fontsize=18 )
                ax.tick_params( axis='both', labelsize=16 )
                if λmin is not None:
                    if isinstance(λmin, list):
                        ax.set_xlim( λmin[targnum], λmax[targnum] )
                    else:
                        ax.set_xlim( λmin, λmax )
                if fmin is not None:
                    if isinstance(fmin, list):
                        ax.set_ylim( fmin[targnum], fmax[targnum] )
                    else:
                        ax.set_ylim( fmin, fmax )
                for λrange in ['B','R','Z']:
                    λ = hdulist[f'{λrange}_WAVELENGTH'].data
                    flux = hdulist[f'{λrange}_FLUX'].data[index]
                    ax.plot( λ, flux, color=plotcolors[λrange] )
                fig.show()
# Out:
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/309/20210407/coadd-3-309-thru20210407.fits : 357
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/312/20210416/coadd-3-312-thru20210416.fits : 278
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/316/20210429/coadd-3-316-thru20210429.fits : 264
