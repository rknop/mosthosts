# %%
# %matplotlib inline
import sys
import os
import math
import pathlib
import logging
import numpy as np
import pandas
import psycopg2
import psycopg2.extras
from matplotlib import pyplot
from mosthosts_desi import MostHostsDesi

# %%
_logger = logging.getLogger( __name__ )
_logger.propagate = False
_logout = logging.StreamHandler( sys.stderr )
_logger.addHandler( _logout )
_logout.setFormatter( logging.Formatter( f'[%(asctime)s - %(levelname)s] - %(message)s' ) )
_logger.setLevel( logging.INFO )

# %%
mhd = MostHostsDesi( release="daily", force_regen=False, logger=_logger )
with open("/global/homes/r/raknop/secrets/decatdb_desi_desi") as ifp:
    dbuser, dbpasswd = ifp.readline().strip().split()
db = psycopg2.connect( host='decatdb.lbl.gov', dbname='desidb', user=dbuser, password=dbpasswd,
                       cursor_factory=psycopg2.extras.RealDictCursor )
# Out:
# [2023-01-04 10:43:06,292 - INFO] - Loading mosthosts table...
# [2023-01-04 10:43:06,935 - INFO] - ...mosthosts table loaded.
# [2023-01-04 10:43:06,950 - INFO] - Read dataframes from pkl files

# %%
db.rollback()
cursor = db.cursor()
cursor.execute( "SELECT DISTINCT ON (snname) * INTO TEMP TABLE mhjustsn FROM static.mosthosts ORDER BY snname" ) 
cursor.execute( "SELECT m1.snname AS snname_1, m2.snname AS snname_2, "
                "       m1.sn_ra AS sn_ra_1, m2.sn_ra AS sn_ra_2, "
                "       m1.sn_dec AS sn_dec_1, m2.sn_dec AS sn_dec_2, "
                "       m1.sn_z AS sn_z_1, m2.sn_z AS sn_z_2, "
                "       m1.program AS program_1, m2.program AS program_2, "
                "       m1.tns_name AS tns_name_1, m2.tns_name AS tns_name_2, "
                "       m1.tns_name AS iau_name_1, m2.iau_name AS tns_name_2, "
                "       m1.tns_name AS ptfiptf_name_1, m2.ptfiptf_name AS tns_name_2 "
                "FROM mhjustsn m1 "
                "INNER JOIN mhjustsn m2 "
                "   ON ABS( (m1.sn_ra - m2.sn_ra)/COS(m1.sn_dec * PI()/180.) ) < 1./3600. "
                "      AND ABS( m1.sn_dec - m2.sn_dec ) < 1./3600. "
                "      AND ( m1.snname != m2.snname ) " )
rows = cursor.fetchall()

# Everything will show up twice because of the inner join.  Try to crop that down.
croprows = {}
for row in rows:
    if ( row['snname_2'], row['snname_1'] ) not in croprows:
        croprows[ ( row['snname_1'], row['snname_2'] ) ] = row

duplicatesne = pandas.DataFrame( croprows.values() )

# %%
duplicatesne
# Out:
#          snname_1      snname_2     sn_ra_1     sn_ra_2   sn_dec_1   sn_dec_2  \
# 0           09hdo         09hdp    3.846665    3.846665  30.722015  30.722015
# 1           11bnx      PTF11bnx  247.580510  247.580500  21.085354  21.085300
# 2           11dzm      PTF11dzm  199.515367  199.515300  42.176136  42.176100
# 3           11mpa      PTF11mpa  256.298517  256.298400  43.900742  43.900800
# 4           11mpg        2007ie  334.402755  334.403000   0.613442   0.613333
# ..            ...           ...         ...         ...        ...        ...
# 136  ZTF19aamljom  ZTF19aampllw  271.538220  271.538160  65.346360  65.346320
# 137  ZTF19aamlkrd  ZTF19aampmfl  259.978064  259.978086  21.008379  21.008374
# 138  ZTF19aampgrt  ZTF19aasneoh  267.819407  267.819490  50.760727  50.760695
# 139  ZTF19aawmcjt  ZTF20aakzbfh  249.769787  249.769772   8.358614   8.358598
# 140  ZTF20aajvyja  ZTF20aakdajy  269.461262  269.461264  33.796737  33.796732
#
#         sn_z_1      sn_z_2            program_1        program_2 tns_name_1  \
# 0       0.0470     0.04700             PTF-iPTF         PTF-iPTF       None
# 1       0.0600 -9999.00000             PTF-iPTF  historical_SNIa       None
# 2       0.0400 -9999.00000             PTF-iPTF  historical_SNIa       None
# 3       0.0320 -9999.00000             PTF-iPTF  historical_SNIa       None
# 4       0.0935     0.09345             PTF-iPTF          SDSS_II       None
# ..         ...         ...                  ...              ...        ...
# 136     0.0200 -9999.00000  RCF/IIps/ZTFmarshal              RCF  SN2019cbc
# 137 -9999.0000 -9999.00000           SNe_Ia/RCF       SNe_Ia/RCF  AT2019bza
# 138 -9999.0000 -9999.00000               SNe_Ia           SNe_Ia       None
# 139     0.0453     0.04500           ZTFmarshal   RCF/ZTFmarshal  SN2020beu
# 140     0.0990 -9999.00000       RCF/ZTFmarshal       ZTFmarshal  SN2020bfe
#
#     tns_name_2 iau_name_1 ptfiptf_name_1
# 0     PTF09hdp       None           None
# 1         None       None           None
# 2         None       None           None
# 3         None       None           None
# 4         None       None           None
# ..         ...        ...            ...
# 136       None  SN2019cbc      SN2019cbc
# 137       None  AT2019bza      AT2019bza
# 138       None       None           None
# 139       None  SN2020beu      SN2020beu
# 140       None  SN2020bfe      SN2020bfe
#
# [141 rows x 14 columns]

# %%
missingindices1 = {}
missingindices2 = {}
sameindices = []
differentradec = {}
for dup in duplicatesne.itertuples():
    df1 = mhd.df.xs( dup.snname_1, level='snname' )
    df2 = mhd.df.xs( dup.snname_2, level='snname' )
    dupdex = ( dup.snname_1, dup.snname_2 )
    for i in df1.index.values:
        if i not in df2.index.values:
            if dupdex not in missingindices1:
                missingindices1[ dupdex ] = [ i ]
            else:
                missingindices1[ dupdex ].append( i )
        else:
            if ( abs( df1.loc[i].ra - df2.loc[i].ra ) / math.cos( df1.loc[i].dec * math.pi / 180. ) > 1./3600. 
                 and abs( df1.loc[i].dec - df2.loc[i].dec ) > 1./3600. ):
                if dupdex not in differentradec:
                    differentradec[ dupdex ] = [ i ]
                else:
                    differentradec[ dupdex ].append( i )
    for i in df2.index.values:
        if i not in df1.index.values:
            if dupdex not in missingindices2:
                missingindices2[ dupdex ] = [ i ]
            else:
                missingindices2[ dupdex ].append( i )
    if ( ( dupdex not in missingindices1 ) and
         ( dupdex not in missingindices2 ) and
         ( dupdex not in differentradec ) ):
        sameindices.append( dupdex )
                
_logger.warning( f"{len(missingindices1)} duplicates have some first indices missing from second, "
                 f"{len(missingindices2)} duplicates have some second indicies missing from first " )
_logger.warning( f"{len(differentradec)} duplicates have hosts with different RA/Dec values" )
_logger.warning( f"{len(sameindices)} duplicates have the same set of hosts" )
# Out:
# [2023-01-04 10:47:58,478 - WARNING] - 16 duplicates have some first indices missing from second, 34 duplicates have some second indicies missing from first
# [2023-01-04 10:47:58,478 - WARNING] - 12 duplicates have hosts with different RA/Dec values
# [2023-01-04 10:47:58,479 - WARNING] - 102 duplicates have the same set of hosts

# %%
print( "**Duplicate SNe in the original mosthosts list with different sets of host indices**" )
for key, val in missingindices1.items():
    snname1, snname2 = key
    dexes1 = mhd.df.xs( snname1, level='snname' ).index.values
    dexes2 = mhd.df.xs( snname2, level='snname' ).index.values
    print( f"    Duplicate SN {snname1} has indexes {' '.join( str(i) for i in dexes1 )}, "
           f"{snname2} has indexes {' '.join( str(i) for i in dexes2 )}" )
print( "(more)" )
for key, val in missingindices2.items():
    if key not in missingindices1:
        snname1, snname2 = key
        dexes1 = mhd.df.xs( snname1, level='snname' ).index.values
        dexes2 = mhd.df.xs( snname2, level='snname' ).index.values
        print( f"    Duplicate SN {snname1} has indexes {' '.join( str(i) for i in dexes1 )}, "
               f"{snname2} has indexes {' '.join( str(i) for i in dexes2 )}" )
        
print( '\n\n**Hosts whose ra/dec don\'t match (w/in 1")**' )
for key, val in differentradec.items():
    ( sn1, sn2 ) = key
    print( f"  SN {sn1} / {sn2} " )
    for i in val:
        print( f"    Index {i} : {sn1} has ({mhd.df.loc[sn1,i].ra}, {mhd.df.loc[sn1,i].dec}) "
               f"while {sn2} has ({mhd.df.loc[sn2,i].ra}, {mhd.df.loc[sn2,i].dec})" )
        
print( '\n\n**Duplicate SNe with the same set of hosts (w/in 1")**' )
for key in sameindices:
    sn1, sn2 = key
    print( f'  {sn1:30s}   {sn2}' )
# Out:
# **Duplicate SNe in the original mosthosts list with different sets of host indices**
#     Duplicate SN 11bnx has indexes 1 2, PTF11bnx has indexes 9
#     Duplicate SN 11dzm has indexes 1, PTF11dzm has indexes 9
#     Duplicate SN 11mpa has indexes 1, PTF11mpa has indexes 9
#     Duplicate SN 11muf has indexes 1, PTF11muf has indexes 9
#     Duplicate SN 11nga has indexes 1 2, PTF11nga has indexes 9
#     Duplicate SN 11oyn has indexes 1, PTF11oyn has indexes 9
#     Duplicate SN 12ena has indexes 1, PTF12ena has indexes 9
#     Duplicate SN 12fuu has indexes 1, PTF12fuu has indexes 9
#     Duplicate SN 13aro has indexes 1 2, PTF13aro has indexes 9
#     Duplicate SN 16auf has indexes 1, iPTF16auf/SN2016ccz/Gaia16aqm/AT2016ccz has indexes 9
#     Duplicate SN 2007jg has indexes 1, SN2007jg has indexes 9
#     Duplicate SN 2007mm has indexes 1 2, SN2007mm has indexes 9
#     Duplicate SN AT2020uth has indexes 9, ZTF20acggviy has indexes 1 2 3
#     Duplicate SN ZTF18aapaohn has indexes 1 2 3, ZTF18aawurud has indexes 1 2
#     Duplicate SN ZTF18aathacy has indexes 1 2 3, ZTF19aaqtyku has indexes 1
#     Duplicate SN ZTF19aamgnnr has indexes 1 2, ZTF19aammewd has indexes 1
# (more)
#     Duplicate SN 16geu has indexes 1, iPTF16geu has indexes 1 2 3
#     Duplicate SN AGN_1183 has indexes 1, ZTF18aazwtkh has indexes 1 2
#     Duplicate SN AGN_1271 has indexes 1, ZTF18acvgnkf has indexes 1 2
#     Duplicate SN AGN_1341 has indexes 1, ZTF18aahpbzs has indexes 1 2 3
#     Duplicate SN AGN_1559 has indexes 1, ZTF19aademoc has indexes 1 2
#     Duplicate SN AGN_1568 has indexes 1, ZTF18aaexhep has indexes 1 2 3
#     Duplicate SN AGN_1656 has indexes 1, ZTF18acahbqb has indexes 1 2 3
#     Duplicate SN AGN_1673 has indexes 1, ZTF18aahqxex has indexes 1 2 3
#     Duplicate SN AGN_1790 has indexes 1, ZTF18aagrkwn has indexes 1 2
#     Duplicate SN AGN_1958 has indexes 1, ZTF18aajnqmp has indexes 1 2
#     Duplicate SN AGN_1960 has indexes 1, ZTF18aaaseqc has indexes 1 2 3
#     Duplicate SN AGN_864 has indexes 1, ZTF18abqarng has indexes 1 2
#     Duplicate SN SN2006gt/SNF20060921-001 has indexes 1 2, SNF20060921-001/SN2006gt has indexes 1 2 3
#     Duplicate SN SN2019azq has indexes 1, ZTF19aamopfr has indexes 1 2
#     Duplicate SN ZTF18aahtjsc has indexes 1, ZTF19aaqhiku has indexes 1 2
#     Duplicate SN ZTF18aaibiuc has indexes 1, ZTF18abdnfho has indexes 1 2
#     Duplicate SN ZTF18aajiwdu has indexes 1, ZTF18aaxqpsg has indexes 1 2 3
#     Duplicate SN ZTF18aawmxdx has indexes 1 2, ZTF19aaflnoi has indexes 1 2 3
#     Duplicate SN ZTF18abfdupq has indexes 1, ZTF18abrxwon has indexes 1 2
#     Duplicate SN ZTF18abhaofa has indexes 1, ZTF18absibtp has indexes 1 2
#     Duplicate SN ZTF19aamjvie has indexes 1, ZTF19aamnwqa has indexes 1 2
#
#
# **Hosts whose ra/dec don't match (w/in 1")**
#   SN AGN_1237 / ZTF18abwnmma
#     Index 1 : AGN_1237 has (330.263077, -0.883365) while ZTF18abwnmma has (330.265110624395, -0.885595591269532)
#   SN AGN_1271 / ZTF18acvgnkf
#     Index 1 : AGN_1271 has (166.41705, 6.707102) while ZTF18acvgnkf has (166.41642465635, 6.70544385916498)
#   SN AGN_1341 / ZTF18aahpbzs
#     Index 1 : AGN_1341 has (141.992328, 22.002239) while ZTF18aahpbzs has (141.998719270943, 21.9992005810656)
#   SN AGN_1559 / ZTF19aademoc
#     Index 1 : AGN_1559 has (166.265021, 7.758589) while ZTF19aademoc has (166.264289996468, 7.75671435062325)
#   SN AGN_1568 / ZTF18aaexhep
#     Index 1 : AGN_1568 has (126.993851, 23.550877) while ZTF18aaexhep has (126.991009074018, 23.5546142633842)
#   SN AGN_1656 / ZTF18acahbqb
#     Index 1 : AGN_1656 has (192.926229, 24.076409) while ZTF18acahbqb has (192.928956886667, 24.0782865465058)
#   SN AGN_1790 / ZTF18aagrkwn
#     Index 1 : AGN_1790 has (251.177199, 26.320355) while ZTF18aagrkwn has (251.177726765166, 26.3168632650176)
#   SN AGN_1958 / ZTF18aajnqmp
#     Index 1 : AGN_1958 has (198.980045, 21.422732) while ZTF18aajnqmp has (198.990132738854, 21.4235287175573)
#   SN AGN_1960 / ZTF18aaaseqc
#     Index 1 : AGN_1960 has (128.74246, 44.0607) while ZTF18aaaseqc has (128.737775473588, 44.0622999488878)
#   SN AGN_864 / ZTF18abqarng
#     Index 1 : AGN_864 has (34.240681, -3.416677) while ZTF18abqarng has (34.2395224657212, -3.41892770995139)
#   SN ZTF18aawmxdx / ZTF19aaflnoi
#     Index 2 : ZTF18aawmxdx has (147.241889553495, 13.9810233985614) while ZTF19aaflnoi has (147.246834291414, 13.9845451066009)
#   SN ZTF18acidntq / ZTF18acqyart
#     Index 2 : ZTF18acidntq has (126.612580652212, 8.73992747693881) while ZTF18acqyart has (126.614481727861, 8.74122640304713)
#
#
# **Duplicate SNe with the same set of hosts (w/in 1")**
#   09hdo                            09hdp
#   11mpg                            2007ie
#   AGN_1184                         ZTF18aauvyug
#   AGN_1252                         ZTF18aarbgrh
#   AGN_1273                         ZTF18aaxlzyf
#   AGN_1384                         ZTF18aahpbal
#   AGN_1827                         ZTF18aahsvob
#   AGN_1860                         ZTF18aacdvjp
#   ASASSN-15rw                      PS15coh/ASASSN-15rw/CSS151031:021558+121414/MLS151211:021558+121414/iPTF15fev
#   AT2018cow                        ZTF18abcfcoo
#   AT2018hjx                        ZTF18acbvahw
#   AT2018ils                        ZTF18aceisbk
#   AT2019fxy                        ZTF19aavwbxs
#   AT202016gou                      ATLAS16cxr/SN2016gou/AT2016gou
#   AT202016ixf                      SN2016ixf/Gaia16cdf/AT2016ixf/PS17bll
#   AT202017dz                       iPTF17dz/SN2017dz/AT2017dz/PS17amw
#   AT2020nlb                        ZTF20abijfqq
#   SN2005lt                         SNF20060125-004
#   SN2006bw/SNF20060520-007         SNF20060520-007/SN2006bw
#   SN2006bz                         SNF20060510-027
#   SN2006ej/SNF20060821-011         SNF20060821-011/SN2006ej
#   SN2007bz/SNF20070422-001         SNF20070422-001/SN2007bz
#   SN2018bgv                        ZTF18aavrmcg
#   SN2020akf                        ZTF20aahdutc
#   ZTF17aacaggx                     ZTF17aacpqfj
#   ZTF18aaaokus                     ZTF18acrdubo
#   ZTF18aabccwc                     ZTF18aahrqeb
#   ZTF18aabxrdf                     ZTF18aabxrjp
#   ZTF18aachnub                     ZTF18acljpra
#   ZTF18aadbtae                     ZTF18aadiimv
#   ZTF18aagtcxj                     ZTF18aagtdce
#   ZTF18aaheszr                     ZTF18aajfeis
#   ZTF18aahjbhp                     ZTF18aaxojwc
#   ZTF18aahpljb                     ZTF18aahptcq
#   ZTF18aahqmsr                     ZTF18aajhdsz
#   ZTF18aaidhnq                     ZTF19aamkfoi
#   ZTF18aaivonj                     ZTF19aaricev
#   ZTF18aakgzwi                     ZTF19aamlfbo
#   ZTF18aakgzwi                     ZTF19aampgss
#   ZTF18aakoejd                     ZTF18aakoejg
#   ZTF18aakpnyt                     ZTF18aclgopa
#   ZTF18aalsiir                     ZTF19abaidez
#   ZTF18aamnsih                     ZTF19abcmrnj
#   ZTF18aampkyo                     ZTF19aampgrt
#   ZTF18aampkyo                     ZTF19aasneoh
#   ZTF18aanuioj                     ZTF18aavxcbe
#   ZTF18aaocokz                     ZTF18aatbdar
#   ZTF18aaoxryq                     ZTF18ablrljh
#   ZTF18aaqpzne                     ZTF19aaxkzts
#   ZTF18aaqxndu                     ZTF18aasxvsg
#   ZTF18aarfpys                     ZTF18adbadly
#   ZTF18aarirzw                     ZTF18aaxckpt
#   ZTF18aarlffl                     ZTF18accnimw
#   ZTF18aarnfbc                     ZTF18acpwodb
#   ZTF18aarnmzg                     ZTF19aaldqkg
#   ZTF18aarvcmx                     ZTF18abobkii
#   ZTF18aasprui                     ZTF18absayvp
#   ZTF18aasrwgz                     ZTF18accwjod
#   ZTF18aauhkzq                     ZTF19aaklqsn
#   ZTF18aauhley                     ZTF18aauhlez
#   ZTF18aavtgcf                     ZTF19aalzmfi
#   ZTF18aavuziy                     ZTF19aawwlxc
#   ZTF18aawdynj                     ZTF19abgpjed
#   ZTF18aawpied                     ZTF19aaedzoh
#   ZTF18abccwgr                     ZTF18abchinz
#   ZTF18abdclel                     ZTF18abqlqhy
#   ZTF18abjdqyv                     ZTF18abkinri
#   ZTF18abolqrn                     ZTF18abomhip
#   ZTF18abrbagb                     ZTF18acsyfsl
#   ZTF18abssuub                     ZTF18adbaeol
#   ZTF18abvfpvi                     ZTF18achplvf
#   ZTF18abyjfyt                     ZTF18abzzebd
#   ZTF18acbufsy                     ZTF19aabhceb
#   ZTF18acbvgqw                     ZTF18adbckhw
#   ZTF18acbvgtu                     ZTF18acfvwiy
#   ZTF18acbwafa                     ZTF18acgxaab
#   ZTF18acbwbbz                     ZTF18acnbelr
#   ZTF18acbxvkv                     ZTF19aakplkf
#   ZTF18acdwoag                     ZTF18acevdkl
#   ZTF18acgxaab                     ZTF18aciebni
#   ZTF18aclkdrz                     ZTF19acrucav
#   ZTF18acnbgux                     ZTF18acnbpsv
#   ZTF18aczassl                     ZTF18aczbjtq
#   ZTF18aczehtp                     ZTF19aaeqkvz
#   ZTF19aaaoytd                     ZTF19aafcgif
#   ZTF19aabkvhe                     ZTF19aaqtxaf
#   ZTF19aalrfnw                     ZTF19aambjkb
#   ZTF19aalrfoi                     ZTF19aambixl
#   ZTF19aalryov                     ZTF19aambzqh
#   ZTF19aamgttu                     ZTF19aammlzn
#   ZTF19aamkfvy                     ZTF19aamohrk
#   ZTF19aamkfxb                     ZTF19aamohsn
#   ZTF19aamkfxg                     ZTF19aamohud
#   ZTF19aamkmxv                     ZTF19aamopcj
#   ZTF19aamkpcd                     ZTF19aamoqxy
#   ZTF19aamkrvb                     ZTF19aamotoi
#   ZTF19aamlfbo                     ZTF19aampgss
#   ZTF19aamljom                     ZTF19aampllw
#   ZTF19aamlkrd                     ZTF19aampmfl
#   ZTF19aampgrt                     ZTF19aasneoh
#   ZTF19aawmcjt                     ZTF20aakzbfh
#   ZTF20aajvyja                     ZTF20aakdajy
